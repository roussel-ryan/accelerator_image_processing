# %%
import matplotlib.pyplot as plt
import numpy as np
from image_processing import get_beam_data

test_image = np.load("test_image.npy")
plt.imshow(test_image)

# %%
get_beam_data(test_image, n_stds=3, visualize=True)
# Out:
# {'Cx': 245.74094317157264,
#  'Cy': 326.47538474202304,
#  'Sx': 15.145715864197523,
#  'Sy': 43.86580418936192,
#  'penalty': -36.07477541367541}
